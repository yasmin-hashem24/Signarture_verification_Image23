# %%
from commonfunctions import *
from Preprocessor import Preprocessor
from Model import *
from ModelScratch import *
from Client import *
# Out:
# WARNING:tensorflow:From c:\Users\sohad\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# #### Training the model

# %%
model = Model()
model.train(real_dir='all/real/', forged_dir='all/forged/')

# %% [markdown]
# #### Model from scratch

# %%
modelScratch = ModelScratch()
modelScratch.train(real_dir='all/real/', forged_dir='all/forged/')
# Out:
# SVM using HOG as feature descriptor. accuracy: 100.0 %
# SVM using HOG as feature descriptor. Testing the train accuracy accuracy: 100.0 %

# %% [markdown]
# ## Model Prediction

# %%
def main():
    if QApplication.instance():
        app = QApplication.instance()
    else:
        app = QApplication(sys.argv)
    model = Model()
    model.loadModel()
    
    window = SigVerifWindow(model)
    window.show()
    app.exec()

if __name__ == '__main__':
    main()
    
# scratch_model = ModelScratch()
# scratch_model.model = load('SVMmodelScratch.pkl')
